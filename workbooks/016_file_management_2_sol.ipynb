# %%
import os
import sys
import pandas as pd

# %% [markdown]
# # File Management 2
#
# ## Pandas File Access
#
# We've already looked at our main tool for reading data from disk, the file read/write functionality in Pandas. When reading datasets this is normally all we need. Inside the read_csv function the Pandas people have either created all the file access stuff that they need to read a CSV or, more likely, they repurposed and extended some os library functions to do the work for them.

# %%
df = pd.read_csv("chipotle.tsv", sep="\t")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## OS and File Read/Write
#
# We can also use the `os` module to do some basic file management. OS is a library that allows us to interact with the operating system on our local computer. Recall that our Python programs run inside an environment setup by the Python install on our computer. This means that as we work we are "inside" that separate environment and we can't directly interact with the underlying computer. The os library, and functions such as read_csv from other libraries, are a tool that allows us to bridge this gap. The os library that is presented to us gives us an assortment of commands to do things like delete files or change the directory we're using. The library's functions are then translated into the correct actions for the actual computer, and passed on to that computer, when the code is run in the Python environment. This also allows for Python code to be portable, or able to run with few to no changes, on different types of computers - I am using a Mac, most of you are probably using a PC, and we can also use a Unix/Linux based system like Google Colab. The code we write can work on all of those environments because of this abstraction, and in each case, the actions triggered by the os module will be different depending on the underlying operating system of the machine. In practice, many of the user-friendly libraries that we might use to access files or folders is built on top of the os module, so we often avoid needing to get into the weeds ourselves.
#
# We can use the `os` module to do things like:
# <ul>
#     <li>Get the current working directory</li>
#     <li>Change the current working directory</li>
#     <li>Get a list of files in a directory</li>
#     <li>Create a new directory</li>
#     <li>Remove a directory</li>
#     <li>Remove a file</li>
# </ul>
#
# First though, let's get some info about our system. Everyone will get totally different results here - I'm on a MacBook Air running MacOS, and I assume most of you have some variety of a PC running Windows. If you've ever seen any of those website things that tells you, "You are running Windows 10 in Edmonton, Ab..." this is a similar idea. The os.uname() function reaches out to the computer and retrieves some of it's identifying information for us.

# %%
for a in os.uname():
    print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\desla\Documents\Data Analytics\Programming_Basics_for_ML\workbooks\016_file_management_2_sol.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/desla/Documents/Data%20Analytics/Programming_Basics_for_ML/workbooks/016_file_management_2_sol.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> for a in os.uname():
#       <a href='vscode-notebook-cell:/c%3A/Users/desla/Documents/Data%20Analytics/Programming_Basics_for_ML/workbooks/016_file_management_2_sol.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     print(a)
#
# AttributeError: module 'os' has no attribute 'uname'

# %% [markdown]
# We can also get much more info by looking at the environment variables. These are variables that are set in the operating system and are available to any program running on the computer. These admittedly not frequently relevant to us doing some data science work, but it is a good example of connecting to the system. One thing that can matter to us is the PATH variable, which (roughly) lists all the places the system will look for programs to run. This is how the system knows where to find Python, for example - its in one of those places - as are all the programs installed on your machine.

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\desla\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_9988_BUBYKHWTDFRLGVDI',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-K4390IN',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': 'C:\\Users\\desla\\miniconda3\\Scripts\\conda.exe',
#         'CONDA_PREFIX': 'C:\\Users\\desla\\miniconda3',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\desla\\miniconda3\\python.exe',
#         'CONDA_ROOT': 'C:\\Users\\desla\\miniconda3',
#         'CONDA_SHLVL': '1',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\desla',
#         'JPY_INTERRUPT_EVENT': '2960',
#         'LOCALAPPDATA': 'C:\\Users\\desla\\AppData\\Local',
#         'LOGONSERVER': '\\\\DESKTOP-K4390IN',
#         'NUMBER_OF_PROCESSORS': '4',
#         'ONEDRIVE': 'C:\\Users\\desla\\OneDrive',
#         'ONEDRIVECONSUMER': 'C:\\Users\\desla\\OneDrive',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\Users\\desla\\miniconda3;C:\\Users\\desla\\miniconda3;C:\\Users\\desla\\miniconda3\\Library\\mingw-w64\\bin;C:\\Users\\desla\\miniconda3\\Library\\usr\\bin;C:\\Users\\desla\\miniconda3\\Library\\bin;C:\\Users\\desla\\miniconda3\\Scripts;C:\\Users\\desla\\miniconda3\\bin;C:\\Users\\desla\\miniconda3\\condabin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\Git\\cmd;C:\\Users\\desla\\AppData\\Local\\Microsoft\\WindowsApps;.;C:\\Users\\desla\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\desla\\Documents\\School Files\\Azure Data Studio\\bin',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 60 Stepping 3, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '3c03',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(base) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHONUTF8': '1',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\Windows',
#         'TEMP': 'C:\\Users\\desla\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\desla\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'DESKTOP-K4390IN',
#         'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-K4390IN',
#         'USERNAME': 'MadDogMike',
#         'USERPROFILE': 'C:\\Users\\desla',
#         'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\desla\\AppData\\Roaming\\Code\\CachedData\\f1b07bd25dfad64b0167beb15359ae573aecd2cc',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\Users\\desla\\AppData\\Local\\Programs\\Microsoft VS Code',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\ac8780a1eb31e2efb4e6482a0298460c-1.83.1-main-sock',
#         'VSCODE_NLS_CONFIG': '{"locale":"en-us","osLocale":"en-ca","availableLanguages":{},"_languagePackSupport":true}',
#         'VSCODE_PID': '9988',
#         'WINDIR': 'C:\\Windows',
#         '_CONDA_OLD_CHCP': '437',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["PATH"].split(":")
# Out:
# ['c',
#  '\\Users\\desla\\miniconda3;C',
#  '\\Users\\desla\\miniconda3;C',
#  '\\Users\\desla\\miniconda3\\Library\\mingw-w64\\bin;C',
#  '\\Users\\desla\\miniconda3\\Library\\usr\\bin;C',
#  '\\Users\\desla\\miniconda3\\Library\\bin;C',
#  '\\Users\\desla\\miniconda3\\Scripts;C',
#  '\\Users\\desla\\miniconda3\\bin;C',
#  '\\Users\\desla\\miniconda3\\condabin;C',
#  '\\Windows\\system32;C',
#  '\\Windows;C',
#  '\\Windows\\System32\\Wbem;C',
#  '\\Windows\\System32\\WindowsPowerShell\\v1.0;C',
#  '\\Windows\\System32\\OpenSSH;C',
#  '\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C',
#  '\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C',
#  '\\Program Files\\Git\\cmd;C',
#  '\\Users\\desla\\AppData\\Local\\Microsoft\\WindowsApps;.;C',
#  '\\Users\\desla\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C',
#  '\\Users\\desla\\Documents\\School Files\\Azure Data Studio\\bin']

# %% [markdown]
# The shutil module is a partner to the os one, and provides some other functions. Among those, we can see disk usage.

# %%
import shutil
shutil.disk_usage("/")
# Out:
# usage(total=249481363456, used=162468724736, free=87012638720)

# %% [markdown]
# ## Folder Management
#
# The OS library also provides for an assortment of folder management functions. We can use these to create, rename, and delete folders.
#
# When using large datasets it is very common to have our data distributed over several folders. For example, if we are doing image recognition we might have a folder for "dogs", another with "cars", and another with "rutabagas". To construct our dataset we need to navigate over all of these folders and read in the files, using os and/or some similar libraries.
#
# Some common folder actions are:
# <ul>
# <li> os.mkdir() - create a new folder </li>
# <li> os.rename() - rename a folder </li>
# <li> os.rmdir() - remove a folder </li>
# <li> os.getcwd() - get the current working directory </li>
# <li> os.chdir() - change the current working directory </li>
# <li> os.listdir() - list the contents of a directory </li>
# </ul>

# %%
os.getcwd()
# Out:
# 'c:\\Users\\desla\\Documents\\Data Analytics\\Programming_Basics_for_ML\\workbooks'

# %% [markdown]
# <b>Note:</b> when using these functions, you need to be careful about where you are in the file system. In particular, the folder location doesn't reset itself automatically if you rerun everything. We need to restart the environment to reset the working directory, or navigate ourselves back to the correct location. The above command got the current working directory back from the Python environment, which in turn got it from the operating system. If we make a change to that directory, then rerun the above cell, we aren't "reset" to the original where we were when we started the program. To do that, we'd need to restart the environment, which would kill this current world in which our program is running, and generate a brand new one.
#
# Here I'm going to capture the current folder name and then move one level up, and back down.

# %%
org_fold = os.getcwd()
tmp = os.getcwd().split("/")[-1]
print(tmp)
os.chdir("../")
os.getcwd()
os.chdir(tmp)
# Out:
# c:\Users\desla\Documents\Data Analytics\Programming_Basics_for_ML\workbooks

# %% [markdown]
# #### Handling File System Data
#
# We can also capture some of this information, and use it as a variable in our code that we can use to navigate the file system. For example, when grabbing the working directory above we stored it as a string and used the split command to break it into a hierarchy of folder names. Below we can pull the files in a folder and that data is returned in a list. If we have code where we need to jump around from folder to folder, we can use this list to help us navigate. For example, if we have a folder structure like this:
#
# ```
# data
#     - dogs
#         - dog1.jpg
#         - dog2.jpg
#         - dog3.jpg
#     - cats
#         - cat1.jpg
#         - cat2.jpg
#         - cat3.jpg
#     - rutabagas
#         - rutabaga1.jpg
#         - rutabaga2.jpg
#         - rutabaga3.jpg
# ```
# Our "base" folder is the data folder, and the subfolders inside are where we'll likely need to do all of our work. We can keep this map of the folder structure in some data structure, then we can use that info to move around. For example, we can find out where we are, visit each subfolder to do some work, and then move back to the base folder.

# %%
# Capture file list
# Print 5
#<b>Bonus:</b> at some point when we looked at strings, someone asked about putting a newline in an f string. I was wrong, it can work like this, no workarounds needed. 
file_list = os.listdir()
print(f"Number of flies: {len(file_list)}\n")
for file in range(5):
    print(file_list[file])
# Out:
# Number of flies: 39
#
# 000_Setup.ipynb
# 001a_python.py
# 001_programming_basics.ipynb
# 002_conditional_statements.ipynb
# 003_loops_old.ipynb

# %% [markdown]
# ### Get Your Walk On
#
# ![Walk](../../images/walk.gif "Walk")
# ![Walk](../images/walk.gif "Walk")
#
# Manually navigating folder structures is pretty useful, but it also sucks and is error prone. The os.walk() function makes this a bit easier for us by doing the "walking" from one folder to another seamlessly.
#
# The os.walk() function returns a generator object, which is a special type of object that we can use to iterate over the contents of a folder. The generator object is a tuple, with the first element being the current folder, the second element being a list of subfolders, and the third element being a list of files. We can use this to iterate over the contents of a folder, and then iterate over the contents of each subfolder, and so on.
#
# The walk function returns a 3 part tuple for us:
# <ul>
#     <li> The current folder </li>
#     <li> A list of subfolders </li>
#     <li> A list of files </li>
# </ul>
#
# We can also use a flag to set if our walker will go top down or bottom up. The default is top down, which means we start at the top level folder and work our way down to the files. If we set the flag to False, we start at the bottom and work our way up. In practice, we pertty much always want top down - we have a folder inside our repository, such as "data" or "logs", and we want to navigate into it. Going the other direction moves "up" and if we leave our repository, that's the computer at large, and it could be anything. This may be useful if you're making an installed application, but most things that we're working on are contained to a specific location, so drilling down is normal.

# %%
walker = os.walk("../")
moonwalker = os.walk("../", topdown=False)

# %%
for root, directories, files, in walker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../
# Directories: ['.git', '.vscode', 'course_material', 'data', 'images', 'moodle_exercises', 'workbooks']
# Files: ['.DS_Store', '.gitignore', 'README.md']
# Root: ../.git
# Directories: ['hooks', 'info', 'logs', 'objects', 'refs']
# Files: ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
# Root: ../.git\hooks
# Directories: []
# Files: ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# Root: ../.git\info
# Directories: []
# Files: ['exclude']
# Root: ../.git\logs
# Directories: ['refs']
# Files: ['HEAD']
# Root: ../.git\logs\refs
# Directories: ['heads', 'remotes']
# Files: []
# Root: ../.git\logs\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\logs\refs\remotes
# Directories: ['origin', 'upstream']
# Files: []
# Root: ../.git\logs\refs\remotes\origin
# Directories: []
# Files: ['main']
# Root: ../.git\logs\refs\remotes\upstream
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\objects
# Directories: ['00', '01', '03', '06', '07', '0b', '0c', '0d', '13', '14', '17', '19', '1a', '1b', '1d', '23', '24', '26', '28', '2c', '2d', '34', '35', '36', '38', '39', '3a', '3b', '3d', '3e', '3f', '40', '41', '43', '44', '46', '47', '48', '49', '4a', '4c', '51', '52', '53', '54', '55', '56', '57', '58', '59', '5e', '60', '61', '62', '64', '65', '66', '6b', '6c', '6e', '6f', '71', '73', '74', '75', '76', '77', '78', '79', '7c', '7e', '7f', '81', '85', '86', '89', '8a', '8b', '8d', '8f', '90', '91', '92', '94', '96', '97', '99', '9a', '9c', '9d', '9e', '9f', 'a0', 'a1', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'aa', 'ab', 'ad', 'ae', 'b1', 'b2', 'b3', 'b4', 'b5', 'b7', 'b8', 'ba', 'bb', 'be', 'bf', 'c0', 'c1', 'c2', 'c4', 'c5', 'c7', 'c8', 'c9', 'ca', 'cb', 'cc', 'ce', 'd3', 'd5', 'd7', 'd8', 'd9', 'dc', 'dd', 'de', 'e0', 'e3', 'e4', 'e5', 'e8', 'e9', 'ea', 'eb', 'ec', 'ed', 'ee', 'f0', 'f3', 'f4', 'f6', 'f8', 'f9', 'fb', 'fe', 'info', 'pack']
# Files: []
# Root: ../.git\objects\00
# Directories: []
# Files: ['15fb1a391f443362f49f9eeb7689c94d6457bd']
# Root: ../.git\objects\01
# Directories: []
# Files: ['025f78bfa3bfe4c985ccd3961492fa7eb925e5', '70c987e5441c8f263700c0eac33a3849ded1d7', 'd6695b9ba44e65a73ebeedd0e95662133fdc11']
# Root: ../.git\objects\03
# Directories: []
# Files: ['9c9a0f23ba90b654038eca8f24836ed4fc3baa', 'e68c106a3491b679853367f2793501ccdae3ae']
# Root: ../.git\objects\06
# Directories: []
# Files: ['4ba28f61d62ccda0dc55361908dc3017885e9e']
# Root: ../.git\objects\07
# Directories: []
# Files: ['136275634b2638c2b7c4a09294650988c6e593', '4318d485202e6c90083a39a049fe5feda13163']
# Root: ../.git\objects\0b
# Directories: []
# Files: ['b1de2ae2d2d94cd5429d6c544fdbae59f6bcb3']
# Root: ../.git\objects\0c
# Directories: []
# Files: ['a09a6b14b872c02c0092e1713cf3a4b74d1297']
# Root: ../.git\objects\0d
# Directories: []
# Files: ['2ccf82360e5194c6c3874f162fe76f3f62d9b6', '4739e0386a4b335541163401179103ea42591b', '82b305f5b560446a4bd96e14ebc9008d1969fd']
# Root: ../.git\objects\13
# Directories: []
# Files: ['1a9c3f6d95aa4127491feec46f4333587c1ba6', '5fbf9c597ad651eae9d14c9a2f009ebffc5727', 'ba26f145bb7ac07c283960cefae69ecb45c350']
# Root: ../.git\objects\14
# Directories: []
# Files: ['f9f569426f1034011873e89b6fce6c3676299c']
# Root: ../.git\objects\17
# Directories: []
# Files: ['f0b8873f4cb35111991ba85e270d6447a83453']
# Root: ../.git\objects\19
# Directories: []
# Files: ['a179f19979d3b9b1c9a337f6c00d10e2fc3149', 'c0d62f6e7e4c7d89319aa92ae4b2e1cec32699', 'cc4ab0dfdc8aa7d768a2a96054a4ffbdd8f728']
# Root: ../.git\objects\1a
# Directories: []
# Files: ['1a42e13ec05b240d6eb23178fa99d8adaff23b', '1ed93077bfaaed2ad22ea8ca303d5ecc259bbb']
# Root: ../.git\objects\1b
# Directories: []
# Files: ['5446508b21d70f4f75c29f4b5ae8624ddb88e3', 'a6958ffcb270fc246cb9cbec1fa43cd73efc62']
# Root: ../.git\objects\1d
# Directories: []
# Files: ['7f1dcdcf1720ddee6e97ae228b56b692e3f156']
# Root: ../.git\objects\23
# Directories: []
# Files: ['733f512cd4fa2ffe6b0f62f961040dc7a1bfa7']
# Root: ../.git\objects\24
# Directories: []
# Files: ['9821564a510b87edbd0af94ec69fda748da6b1', 'a13f061e6118663fa20557ffc7bea124dba909']
# Root: ../.git\objects\26
# Directories: []
# Files: ['5c518631dffb44719daba839284cf70a958ea8', 'eba2cb54e09a9858aa3609cf211722a4dd349f']
# Root: ../.git\objects\28
# Directories: []
# Files: ['5c046495a405ef93857b3ddb38e3b498c9c94a']
# Root: ../.git\objects\2c
# Directories: []
# Files: ['8189a300c09e8016e2e08a6a9e1e08282ecd4c']
# Root: ../.git\objects\2d
# Directories: []
# Files: ['cae1b5fd2bf5d19b4502c22d0314bb16f81c64']
# Root: ../.git\objects\34
# Directories: []
# Files: ['4e1dfb04b0885d82abc80333cca6cde479b45d', '8e8a7d5b79f7a7471edbbecd3850d9e32f7a96']
# Root: ../.git\objects\35
# Directories: []
# Files: ['4642af3d614a08aeac27123d02a3f3a2c8ca92']
# Root: ../.git\objects\36
# Directories: []
# Files: ['d6f99206791e83deb46dc08e5be73c1fec5b4a']
# Root: ../.git\objects\38
# Directories: []
# Files: ['20a7758d8a6825b4959891102d59047ed0428a', 'cba4f93e92a0f0acc1887df1ca07952e4db9f0']
# Root: ../.git\objects\39
# Directories: []
# Files: ['7ebd753591bfeea83ef740c2307cdd3346aac0']
# Root: ../.git\objects\3a
# Directories: []
# Files: ['84bbf32a4e8deb2b027dc2ac5d7751ab4852e1', 'eff18bad35aa5a0c3f0291f31ca86760f8d3f5']
# Root: ../.git\objects\3b
# Directories: []
# Files: ['ed60ccd0082a06c0ef93caf5805a6c6e54491a']
# Root: ../.git\objects\3d
# Directories: []
# Files: ['b70111c9b958a9791106b65d348fbfad382a19']
# Root: ../.git\objects\3e
# Directories: []
# Files: ['8bba541eff5c7e06c33afaa16bd32726a38022']
# Root: ../.git\objects\3f
# Directories: []
# Files: ['54c38b1e44ca9479b12a80ae505d56fce73e2a']
# Root: ../.git\objects\40
# Directories: []
# Files: ['7fc6dfae9e259b51d7b8ab675a5c10f26742ff']
# Root: ../.git\objects\41
# Directories: []
# Files: ['169e94342ea6bf1a6392ca0521e76b4858c5a1', '239071297be799d9082035bad8801b968303a3']
# Root: ../.git\objects\43
# Directories: []
# Files: ['4563540cac3556b02fe654cc763b139592213f', '4ffea6ceda50fe50cbca23c2b29a63600b572f']
# Root: ../.git\objects\44
# Directories: []
# Files: ['2af3229c2ae16e938b4f1f1862d744a0cfea8c', 'f88ede05f78c61f08696a64b9c879791b868e3']
# Root: ../.git\objects\46
# Directories: []
# Files: ['8aab640e2260120853f5aac2df1c69360d20ac']
# Root: ../.git\objects\47
# Directories: []
# Files: ['384b15c4e4e92f2436f2128aa212ab4ea733ba']
# Root: ../.git\objects\48
# Directories: []
# Files: ['5cc18e04d1afb3fc754ca9214107b8235b0781']
# Root: ../.git\objects\49
# Directories: []
# Files: ['093877b08c06374396f112262c06d9eee62fe0', 'db74c4456ac9108280c3b2984be4b5455f38e3']
# Root: ../.git\objects\4a
# Directories: []
# Files: ['7b0262719a0b00a52ee94a7044c5bd9d1f9f89']
# Root: ../.git\objects\4c
# Directories: []
# Files: ['d82571b386ba9ac42a984826f8d34963ddc39e']
# Root: ../.git\objects\51
# Directories: []
# Files: ['4ca9e261e303d49b1371491b513cd793d56e98']
# Root: ../.git\objects\52
# Directories: []
# Files: ['478777250fec96d00c720786b02e499754425f', '558e2b53ffe0c8263f7d16eba79c76fdfb73a5', 'ca6f4ebb6126c8eee0e264d7f6fd38f63aea83']
# Root: ../.git\objects\53
# Directories: []
# Files: ['6bc1721c667ba0383759628f09708d2be5a449']
# Root: ../.git\objects\54
# Directories: []
# Files: ['fa495c9750894b2dcd679f56dde1df94cb7fa6']
# Root: ../.git\objects\55
# Directories: []
# Files: ['9f6b629e709e1659df7c8403b6f9966c8e9354']
# Root: ../.git\objects\56
# Directories: []
# Files: ['4b2fa2d79c7c38af4d2b264bd5ea316634e759', 'df546c2f2fa0008d646265798481ba409aa35f']
# Root: ../.git\objects\57
# Directories: []
# Files: ['40c6f80204f80a846fd19dc8269cfdb84a265d', '88b18e1da6e4fec36aa070f2ad57476b745b27']
# Root: ../.git\objects\58
# Directories: []
# Files: ['2427180575a1df40b245a590c488453b332c8b', '9a1ab8f2a1811ce8f58a23c029abd39575d617']
# Root: ../.git\objects\59
# Directories: []
# Files: ['644d280ca8e2519da18b59d36b85c8ff656572']
# Root: ../.git\objects\5e
# Directories: []
# Files: ['2d7c0f793e22f42c3508a077b2954ce13d8436']
# Root: ../.git\objects\60
# Directories: []
# Files: ['162e2e8632fe5aea3898afaf6f0dfc6925be9d', '6ae6c96dffe28154a65c710582f60d2da225bc']
# Root: ../.git\objects\61
# Directories: []
# Files: ['46222f99f39ef996b74c897b62a3acfea4da47', '479f9e6df900bc836389475a6c783b34adda04', '6709ff81d3837c9bc2dcb4e6d98a095fa815bc']
# Root: ../.git\objects\62
# Directories: []
# Files: ['9f06a5df70c96ef9f966bcde183cebc20daebb']
# Root: ../.git\objects\64
# Directories: []
# Files: ['219d3c192d4e428fcde71e0d2b9bc8031eb2e7', '4dab7944ffb7845359370e85f91235c92476ac']
# Root: ../.git\objects\65
# Directories: []
# Files: ['5ccbf4abc917c5b2fb2d7a2602dd85bdd4ae40']
# Root: ../.git\objects\66
# Directories: []
# Files: ['a3082345b6617970f20cbcc0fb3b580330a4d5']
# Root: ../.git\objects\6b
# Directories: []
# Files: ['1ea05f3ea7a63bd704318a69811ea881556542', '73b1258c20c6502d1eb56c7c1b2f029b4b94dd']
# Root: ../.git\objects\6c
# Directories: []
# Files: ['022723dd0786fea5d9333e30644ea9eb6f46c7']
# Root: ../.git\objects\6e
# Directories: []
# Files: ['30467e7d51df7a5861cbec047f1691b76eac67']
# Root: ../.git\objects\6f
# Directories: []
# Files: ['65d8dc7ae03bc53adbfe93f035b62889f9c78d', 'c106622be6233fe407d55a2116f87408ee29a4']
# Root: ../.git\objects\71
# Directories: []
# Files: ['1419cd906c4dc67e290bc026430c2ba862af1c', '7bbaa1fa36adc17b7c5a2ae45f38f3a80e4ad0']
# Root: ../.git\objects\73
# Directories: []
# Files: ['6bd92eac126465b3bee027e2479709783adbf5']
# Root: ../.git\objects\74
# Directories: []
# Files: ['38979d3ff8e1a12e9a3ca4bb39766b55a3f1d6', 'eb568bd71f239f12d5dc091376cf2c68ac574f']
# Root: ../.git\objects\75
# Directories: []
# Files: ['46b8c59c3380c6ddb5db3b906be25b0180c00a', '68ad1ba253a6736e6d55ed61b12691d4c96939', 'fe24da23cadb56f3b3624d36692451b07efdfd']
# Root: ../.git\objects\76
# Directories: []
# Files: ['6d38ccf9dd200061fb2f031616bdb63776e47c']
# Root: ../.git\objects\77
# Directories: []
# Files: ['fc9ae27ac7f5d2b68dc5cf01fbe8712faddd8f']
# Root: ../.git\objects\78
# Directories: []
# Files: ['ea61711f6ca43ce2de70680921e67f3eadac3b']
# Root: ../.git\objects\79
# Directories: []
# Files: ['afa3b240b80b9a6573b10d0d52fbf7354b010c']
# Root: ../.git\objects\7c
# Directories: []
# Files: ['1c6e665bec5cdf0d1976af8e0e79a0dbf394c8', 'f2b156bcba22f158f428616f8c1dbf9e395918']
# Root: ../.git\objects\7e
# Directories: []
# Files: ['47ffdfa05a3dd974a44d028aac6b4990496b5a', '7636a709c2a9eeedb3f6e168b0a93b7890a072']
# Root: ../.git\objects\7f
# Directories: []
# Files: ['90a66789ab14c90484849dd0d1a6124bb535d6']
# Root: ../.git\objects\81
# Directories: []
# Files: ['5b1a9d26a07b3d9cf7687deba07df667a3cbfb']
# Root: ../.git\objects\85
# Directories: []
# Files: ['2749334bf2cdfe7908e8e4f60b342bedb2d98e', 'ee47e75898ee57914f8619a742195732e551e7']
# Root: ../.git\objects\86
# Directories: []
# Files: ['eb62ab16a98cea56833c547a3075e057f33926']
# Root: ../.git\objects\89
# Directories: []
# Files: ['690db6b354b6745938bb442e0c31ffa9b0498f']
# Root: ../.git\objects\8a
# Directories: []
# Files: ['7b4fa1c3bce33b6ae127533140cd8fb56e0132', '9472ecc99f49466fc94d945249d7c8032054ac']
# Root: ../.git\objects\8b
# Directories: []
# Files: ['9903d541c6d6e00ee4dfd24531ceed4358a0a7']
# Root: ../.git\objects\8d
# Directories: []
# Files: ['028fa4b92e8b095da5298edb9a45e0db5b7244', '15c730ff44433300391faeecb700af0ac24ad3']
# Root: ../.git\objects\8f
# Directories: []
# Files: ['474a56060e520d3b048c0fecbebb71ea8f4ed4']
# Root: ../.git\objects\90
# Directories: []
# Files: ['37b8b9ce9bf2da37fab0df236c8a50c53f9761', '4b2f14f07d0ef8385e2b34d0132416c94d01aa']
# Root: ../.git\objects\91
# Directories: []
# Files: ['6eb78409b5b486d4416d2d3acd5d3ddea09950']
# Root: ../.git\objects\92
# Directories: []
# Files: ['3f6c828d4bc63191348a5057c43aa37471159b', 'af5de0139bed3e08cc7e27b13a084df1668c45']
# Root: ../.git\objects\94
# Directories: []
# Files: ['74240172820ac8bca98860ad94efccd1192228']
# Root: ../.git\objects\96
# Directories: []
# Files: ['49215a1390297751f95ce42a92000ed3e2747f']
# Root: ../.git\objects\97
# Directories: []
# Files: ['37876c13aebe49270684746fa925c1bf732ae8', '530b67ad21a3c97eb4ac21ebc3b8afd52170b5']
# Root: ../.git\objects\99
# Directories: []
# Files: ['18e523d2664b426d4a4424b201e5b14fd7081f']
# Root: ../.git\objects\9a
# Directories: []
# Files: ['1eb5660ae98865b86310c997403a50653141e0', 'b3a73969e97e6c96a912db3f4b4f8a5b4b8d3d']
# Root: ../.git\objects\9c
# Directories: []
# Files: ['54175c25b8e2f23c511d8c702de925bfe7ace9']
# Root: ../.git\objects\9d
# Directories: []
# Files: ['1cf8004ce4de62f64c1f5f9069e3a584a67483', '2927665ca4d9e05560a48483423b026cd9bcba']
# Root: ../.git\objects\9e
# Directories: []
# Files: ['5157240f0864cda360dcee1319df60fe368fec']
# Root: ../.git\objects\9f
# Directories: []
# Files: ['9e7afa2d256dce9b8a7caa36015cf6eb505822']
# Root: ../.git\objects\a0
# Directories: []
# Files: ['3260b158ac901b8c3cd78baf3cbac5d2607711']
# Root: ../.git\objects\a1
# Directories: []
# Files: ['10b9404bb7859451961fb239da820c09910ea0', 'f20ce842f646800bc3f468078d78a5ddcb7786']
# Root: ../.git\objects\a3
# Directories: []
# Files: ['3ea398da2192d1343207d83227efb68bb6a056']
# Root: ../.git\objects\a4
# Directories: []
# Files: ['e6a3016b7ddc87f998a451daf26a442638780e']
# Root: ../.git\objects\a5
# Directories: []
# Files: ['1af31d98c1012d2aec0de8de5eff8de20f1a42']
# Root: ../.git\objects\a6
# Directories: []
# Files: ['54c99da45924e0233efae8f4c3830628a6eb5c']
# Root: ../.git\objects\a7
# Directories: []
# Files: ['f25c0e9f8b2b3457a9ec419fbe8573bcad56b9']
# Root: ../.git\objects\a8
# Directories: []
# Files: ['1dd55437406a9c25e563c2b888cdb990d4d375', 'ff9453134452ea17d3d2c7c3594ae5c5b8592f']
# Root: ../.git\objects\a9
# Directories: []
# Files: ['0d0dffe0a72fdcda0e9155f9cd3263eabca3f3']
# Root: ../.git\objects\aa
# Directories: []
# Files: ['0a03591b94e0f3e454b0b8ac813a70ef5e7771']
# Root: ../.git\objects\ab
# Directories: []
# Files: ['597a1d81a905c043da00c9bdfc89592cb3dd10']
# Root: ../.git\objects\ad
# Directories: []
# Files: ['d4e571bd8d89bd8fc4c3b194d5f251c0a44d99']
# Root: ../.git\objects\ae
# Directories: []
# Files: ['49a50968209524765f7be978f3cf8bcc190ea0']
# Root: ../.git\objects\b1
# Directories: []
# Files: ['8179d6311daebc3f0f71276bd518272c97d7fb', 'fba9b9688b1db8b9b9b329578de1124ea05c84']
# Root: ../.git\objects\b2
# Directories: []
# Files: ['42572efb85a6962e35561c9b54f513a3ab5803']
# Root: ../.git\objects\b3
# Directories: []
# Files: ['62098b9374f153670ba8227ee6606eeffaa664']
# Root: ../.git\objects\b4
# Directories: []
# Files: ['8cc88f2e25393714e40990a46b160faf3936ef', '9916b3c0da05eb89e3a4a94b8359cd2bce0447']
# Root: ../.git\objects\b5
# Directories: []
# Files: ['df5adf97a7e3e2cac263353f852e1136c66165']
# Root: ../.git\objects\b7
# Directories: []
# Files: ['b6075e5361e54605fbf025276f32006811e83a']
# Root: ../.git\objects\b8
# Directories: []
# Files: ['0be544604284378f37eb28195df20fa78db24a', '9927dfd56589de6a49dcec28d27d73ae58ccd8', 'c07578500a599cb35b8c3266b9d27411f62268']
# Root: ../.git\objects\ba
# Directories: []
# Files: ['a6c4484456d06296d970babd8e5bc50455d4b2']
# Root: ../.git\objects\bb
# Directories: []
# Files: ['3778dc22ea26d64620fa3ea25150cb3cc3ea0a']
# Root: ../.git\objects\be
# Directories: []
# Files: ['58ffc42971512a6dd2cc889b825df70964bf06']
# Root: ../.git\objects\bf
# Directories: []
# Files: ['dde7f66dc7fda3f1becf35c575281bfe22a92b', 'e951fba7b4f0292883852bfd00a5a74f4efb18']
# Root: ../.git\objects\c0
# Directories: []
# Files: ['41cb8fe9a48e976c71bf5157f365332a190c3c', '7372c513630f624a4ebcd66b52d954879ac1e6', 'c812671f590ad91fc3dba6901accc13fcfb5da', 'fea367cd3bf021197b609c96031039d024ba9f']
# Root: ../.git\objects\c1
# Directories: []
# Files: ['4de19b18afae46a40ceeb3fb79b44144ae81af', '66b0052670d883a8aded1614caeadd85297727']
# Root: ../.git\objects\c2
# Directories: []
# Files: ['bc5a5d49e558414c059de8cb5f5fc813798da3']
# Root: ../.git\objects\c4
# Directories: []
# Files: ['4b6195cbd098207e0112ff09355549cfb300a1', '8b54aa599a2b0845d70bc1b9f2154e3e6659b7', 'ef71126e8d6a64c5c8e4ea419bc1f20b6f46d1']
# Root: ../.git\objects\c5
# Directories: []
# Files: ['809c6834947c190e646b827b7449d7f24cccee', '859bbe0671609da22d0fe2065f289ff02d8e97', 'bc65d8df17b08070cf2e815416a8808c54d279']
# Root: ../.git\objects\c7
# Directories: []
# Files: ['c99206daacc01b458a8d23287d65a9a8a84228']
# Root: ../.git\objects\c8
# Directories: []
# Files: ['2de6f34e63ac84bb6429f0e0b8aa46b810d4ed', '3ce945e8ce70e26d395ae9ab4fde614ebb1c84']
# Root: ../.git\objects\c9
# Directories: []
# Files: ['bd47ff212002ea26d7cf98b0c78f3f99c5f0ea', 'f6f310bf81c418237dd6acae3e8207a6833450']
# Root: ../.git\objects\ca
# Directories: []
# Files: ['b80a04959462b0cd055134f50752f8604b3a52']
# Root: ../.git\objects\cb
# Directories: []
# Files: ['aa49810379df737f6aabf97c13f36f2a1eed59']
# Root: ../.git\objects\cc
# Directories: []
# Files: ['61011d9db4dd6f394f89f2a46ef7ae0668acc9']
# Root: ../.git\objects\ce
# Directories: []
# Files: ['b6b722a26ba095f470199ef23779299b71d5f1']
# Root: ../.git\objects\d3
# Directories: []
# Files: ['d2cea78683ab486ee402a72da6f77821c7471b']
# Root: ../.git\objects\d5
# Directories: []
# Files: ['2fabba1c6c1fb1da5bad5523e2e69922929a1a', 'f9522f7df61f2fd2be8f4e255226dbcaf4ac72']
# Root: ../.git\objects\d7
# Directories: []
# Files: ['22f7694329cb626a86c0b5551decf8120776c2']
# Root: ../.git\objects\d8
# Directories: []
# Files: ['dfa00c0c568980ba3bdd49a968a2ed32c0782f']
# Root: ../.git\objects\d9
# Directories: []
# Files: ['0a512747514b67af049e7b7d20e6a11c441618', '7e8651cd2fc6a8d65af9fbe77c3160b838a01d', 'fa9b3987c9ac4ae41fce968b46d0544c721c9d']
# Root: ../.git\objects\dc
# Directories: []
# Files: ['c182b3d78b98fc729721eab90d5c39a9c212d9', 'cc2d0fcba7d8c8c1bd22761e221e0ea8bba31d']
# Root: ../.git\objects\dd
# Directories: []
# Files: ['c1b3db4e99c142bc44007e7ebb9691565c3e46']
# Root: ../.git\objects\de
# Directories: []
# Files: ['bd5c420d1e1f23d41686a5c7f24b484e2cefa7', 'c0552138655a6b3f14ebbbfcce27df86e88339', 'd4473570c91d5a5efcbde3f9c74b3c253d3ea0']
# Root: ../.git\objects\e0
# Directories: []
# Files: ['e361c3c0c00e6d5ea2857382afe25194579921']
# Root: ../.git\objects\e3
# Directories: []
# Files: ['8f0b2000019abd6c58d1d6a4dba2a4ff85bded']
# Root: ../.git\objects\e4
# Directories: []
# Files: ['a9b7e330b9b5faab16560863ba432f8c0a584f', 'ab7cf694ff758e9f6adb9b9ab9785a80e81837']
# Root: ../.git\objects\e5
# Directories: []
# Files: ['3e0ec887ef861426edee15b40285e09c59d64c', '7b98c0cd73de15a91f21e15e15f4e6b93c11f9']
# Root: ../.git\objects\e8
# Directories: []
# Files: ['abe20bb409ad4a9cc3e84efc5dab1e066f5bc7']
# Root: ../.git\objects\e9
# Directories: []
# Files: ['e2f24a11a3fa645ca6dfebecbfa1f4c45e2fe8', 'ec75f479bd678010a185fd00bc97a59a30cc8c']
# Root: ../.git\objects\ea
# Directories: []
# Files: ['588e3b3f5bf4a0cfc12d3392113c71a66ea8e5']
# Root: ../.git\objects\eb
# Directories: []
# Files: ['f002841663b9cbc70db8ff6d817fc4a88d1721']
# Root: ../.git\objects\ec
# Directories: []
# Files: ['1b79a286aac036211037c3de5a10384c5f2b2a', '885491b57813df79f910633e23c4cf82632d62']
# Root: ../.git\objects\ed
# Directories: []
# Files: ['a2e1d90698178968b8334e1062548b70b59fe4']
# Root: ../.git\objects\ee
# Directories: []
# Files: ['0e672ceb39eea2b01f23d1165d6d2bd7cd8e65', '2a1f651cd5df4cd587a791ac75d4fd18a7e54b']
# Root: ../.git\objects\f0
# Directories: []
# Files: ['004ac67dd52da364e35e8dba35d5fe3d85081e', '07dd98e0a9b3f35b09aa95045e53f8f4074f56', 'abb5b2f6b5101076213b60ffc2cec05e5048f4']
# Root: ../.git\objects\f3
# Directories: []
# Files: ['5de938ae7e7d7e36741025e0e337a676645b41']
# Root: ../.git\objects\f4
# Directories: []
# Files: ['9f3ebdce693c77b4221aa79e72599bcb9208d2']
# Root: ../.git\objects\f6
# Directories: []
# Files: ['273fa7c230984cf401bc960a703b5d5a5c075d', '933be5ad82d6a9d8eed78e220810b710bc61b5', 'fba4dac80160967d820289a31470d5f0c67a93']
# Root: ../.git\objects\f8
# Directories: []
# Files: ['4d2986d94ec51cd9406ef272f29716e1163e8c', 'c6449d8458f6e325663928c183529a4d8c34a0', 'd9bc3c0ecae0e50280eb683d32563ca4fa2eef']
# Root: ../.git\objects\f9
# Directories: []
# Files: ['0e3871e9c3013586e65437ead2eb1636f2730f', 'af0c06b9cbdf388b9b33a5ea6368776e33a856']
# Root: ../.git\objects\fb
# Directories: []
# Files: ['2b44af49b0dfd538d5d7983a7167afc8ce9af7', '7e8460d79755e6d17e94026b0581e52ad8baf3']
# Root: ../.git\objects\fe
# Directories: []
# Files: ['c9ff76a43b37312b9531fef7a32b05ca5b6a43']
# Root: ../.git\objects\info
# Directories: []
# Files: []
# Root: ../.git\objects\pack
# Directories: []
# Files: ['pack-5165df150c8267cb87e8b0966817a8208ef5cc04.idx', 'pack-5165df150c8267cb87e8b0966817a8208ef5cc04.pack', 'pack-5165df150c8267cb87e8b0966817a8208ef5cc04.rev']
# Root: ../.git\refs
# Directories: ['heads', 'remotes', 'tags']
# Files: []
# Root: ../.git\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\refs\remotes
# Directories: ['origin', 'upstream']
# Files: []
# Root: ../.git\refs\remotes\origin
# Directories: []
# Files: ['main']
# Root: ../.git\refs\remotes\upstream
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\refs\tags
# Directories: []
# Files: []
# Root: ../.vscode
# Directories: []
# Files: ['settings.json']
# Root: ../course_material
# Directories: ['slides']
# Files: ['.DS_Store', 'syllabus_1231.docx']
# Root: ../course_material\slides
# Directories: []
# Files: ['002_vars_and_control.pptx', '003_loops.pptx', '004_functions.pptx', '005_file_access.pptx', '006_classes_obj_1.pptx', '007_other_data_structures.pptx', '008_recursion.pptx', '009_comments_enum.pptx', '012_algo_interface_errors.pptx', '013_arrays.pptx', '014_bulk_actions.pptx', '015_overload.pptx', '017_arg_kwarg.pptx', '018_cards_2.pptx', '1 - Intro Machine Learning.pptx', 'inheritance.pptx', 'os_system.pptx']
# Root: ../data
# Directories: []
# Files: ['HeightWeight.csv', 'sportsref_download.xlsx', 'threads_reviews.csv', 'titanic_train.csv']
# Root: ../images
# Directories: []
# Files: ['df.webp', 'dict_list.jpg', 'dict_list.png', 'factorial.png', 'fact_breakdown.png', 'for_loop.jpg', 'for_loop.png', 'harvard_grades.webp', 'if_else.png', 'logic-gates.webp', 'make_dict.jpg', 'marvin.png', 'nested_for.png', 'nested_if.png', 'python-sets.jpg', 'recursion.png', 'set_operations.png', 'var_scope.webp', 'while_loop.png']
# Root: ../moodle_exercises
# Directories: []
# Files: ['10_Day_1_Object_Oriented_Programming.ipynb', '11_Inheritance_.ipynb', '1_exapmles.ipynb', '1_racing cars.ipynb', '2_Day_1.ipynb', '2_Examples.ipynb', '2_More Exercises.ipynb', '3 Day 1.ipynb', '4_Day_1.ipynb', '6 Day 1 - Lists and Functions.ipynb', '7_Day_1_Files_and_exceptions.ipynb', 'Week_9_Day_Sets_and_Dictionaries.ipynb']
# Root: ../workbooks
# Directories: ['development_working_dir', 'file_list']
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops_old.ipynb', '004_functions.ipynb', '004_functions_old.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', '009_strings.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '012_algorithm_design_sol.ipynb', '013_arrays_and_numpy.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply.ipynb', '014_map_apply_sol.ipynb', '015_overloading.ipynb', '015_overloading_sol.ipynb', '016_file_management_2.ipynb', '016_file_management_2_sol.ipynb', '017a_cards.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs.ipynb', '017_args_kwargs_sol.ipynb', '017_inheritance.ipynb', '017_inheritance_sol.ipynb', 'chipotle.tsv', 'fib.csv', 'file_list.zip', 'helper.py']
# Root: ../workbooks\development_working_dir
# Directories: []
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops.ipynb', '004_functions.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', 'helper.py', 'z00_classes.ipynb', 'z00_class_comments.ipynb']
# Root: ../workbooks\file_list
# Directories: []
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops_old.ipynb']

# %%
for root, directories, files, in moonwalker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../file_list
# Directories: []
# Files: ['010_class_comments.ipynb', '011_looping_2_data.ipynb', '005_file_access.ipynb', '007_other_data_structures_full_sol.ipynb', '.DS_Store']
# Root: ../development_working_dir/file_list/file_list
# Directories: []
# Files: []
# Root: ../development_working_dir/file_list
# Directories: ['file_list']
# Files: ['010_class_comments.ipynb', 'Clothing.csv', '005_file_access.ipynb', '.DS_Store', '006_objects.ipynb']
# Root: ../development_working_dir
# Directories: ['file_list']
# Files: ['010_class_comments.ipynb', 'Clothing.csv', '005_file_access.ipynb', '006_objects.ipynb', 'residential.csv', 'Cycling.csv', '002_conditional_statements.ipynb', 'z00_classes.ipynb', 'Car Electronics.csv', 'overloading_sol.ipynb', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', '016_file_management_2.ipynb', 'COPY-Asn_1_sol.ipynb', '013_arrays_and_numpy_sol.ipynb', 'run_from_command.py', 'inheritance.ipynb', '011_looping_2_data_sol.ipynb', '014_map_apply_sol.ipynb', 'Strength Training.csv', 'fib.csv', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', 'multip_inh.ipynb', 'residential2.csv', '000_Setup.ipynb', '001a_python.py', 'chipotle.tsv', 'tmp.ipynb', '001_programming_basics.ipynb', 'arrays_and_numpy_sol.ipynb', 'string_processing.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', '008_recursion.ipynb']
# Root: ../__pycache__
# Directories: []
# Files: ['helper.cpython-310.pyc']
# Root: ../
# Directories: ['file_list', 'development_working_dir', '__pycache__']
# Files: ['010_class_comments.ipynb', '011_looping_2_data.ipynb', '005_file_access.ipynb', '007_other_data_structures_full_sol.ipynb', '.DS_Store', '006_objects.ipynb', '012_algorithm_design_sol.ipynb', '002_conditional_statements.ipynb', '005a_File_Loading_example_from_stats.ipynb', '004_functions.ipynb', '009_strings_sol.ipynb', 'COPY-012_algorithm_design copy.ipynb', 'COPY-015_overloading.ipynb', '013_arrays_and_numpy_sol.ipynb', '009_strings.ipynb', '011_looping_2_data_sol.ipynb', '014_map_apply.ipynb', '014_map_apply_sol.ipynb', 'COPY-014_map_apply.ipynb', 'fib.csv', 'file_list.zip', 'helper.py', '012_algorithm_design.ipynb', '013_arrays_and_numpy.ipynb', '000_Setup.ipynb', '001a_python.py', 'chipotle.tsv', '015_overloading_sol.ipynb', '001_programming_basics.ipynb', 'COPY-013_arrays_and_numpy.ipynb', '007_other_data_structures.ipynb', '003_loops.ipynb', '015_overloading.ipynb', '008_recursion.ipynb']

# %% [markdown]
# ## Exercise
#
# Attempt to list the folders and files in the level above where this notebook is located. Create a list of folders and a list of files. Return them in a tuple.

# %%
def genList(path="../"):
    folders = []
    files = []
    for root, directories, files in os.walk(path):
        folders.append(root)
        folders.append(directories)
        files.append(files)
    return folders, files

# %%
genList()[0]
# Out:
# ['../',
#  ['.git',
#   '.vscode',
#   'course_material',
#   'data',
#   'images',
#   'moodle_exercises',
#   'workbooks'],
#  '../.git',
#  ['hooks', 'info', 'logs', 'objects', 'refs'],
#  '../.git\\hooks',
#  [],
#  '../.git\\info',
#  [],
#  '../.git\\logs',
#  ['refs'],
#  '../.git\\logs\\refs',
#  ['heads', 'remotes'],
#  '../.git\\logs\\refs\\heads',
#  [],
#  '../.git\\logs\\refs\\remotes',
#  ['origin', 'upstream'],
#  '../.git\\logs\\refs\\remotes\\origin',
#  [],
#  '../.git\\logs\\refs\\remotes\\upstream',
#  [],
#  '../.git\\objects',
#  ['00',
#   '01',
#   '03',
#   '06',
#   '07',
#   '0b',
#   '0c',
#   '0d',
#   '13',
#   '14',
#   '17',
#   '19',
#   '1a',
#   '1b',
#   '1d',
#   '23',
#   '24',
#   '26',
#   '28',
#   '2c',
#   '2d',
#   '34',
#   '35',
#   '36',
#   '38',
#   '39',
#   '3a',
#   '3b',
#   '3d',
#   '3e',
#   '3f',
#   '40',
#   '41',
#   '43',
#   '44',
#   '46',
#   '47',
#   '48',
#   '49',
#   '4a',
#   '4c',
#   '51',
#   '52',
#   '53',
#   '54',
#   '55',
#   '56',
#   '57',
#   '58',
#   '59',
#   '5e',
#   '60',
#   '61',
#   '62',
#   '64',
#   '65',
#   '66',
#   '6b',
#   '6c',
#   '6e',
#   '6f',
#   '71',
#   '73',
#   '74',
#   '75',
#   '76',
#   '77',
#   '78',
#   '79',
#   '7c',
#   '7e',
#   '7f',
#   '81',
#   '85',
#   '86',
#   '89',
#   '8a',
#   '8b',
#   '8d',
#   '8f',
#   '90',
#   '91',
#   '92',
#   '94',
#   '96',
#   '97',
#   '99',
#   '9a',
#   '9c',
#   '9d',
#   '9e',
#   '9f',
#   'a0',
#   'a1',
#   'a3',
#   'a4',
#   'a5',
#   'a6',
#   'a7',
#   'a8',
#   'a9',
#   'aa',
#   'ab',
#   'ad',
#   'ae',
#   'b1',
#   'b2',
#   'b3',
#   'b4',
#   'b5',
#   'b7',
#   'b8',
#   'ba',
#   'bb',
#   'be',
#   'bf',
#   'c0',
#   'c1',
#   'c2',
#   'c4',
#   'c5',
#   'c7',
#   'c8',
#   'c9',
#   'ca',
#   'cb',
#   'cc',
#   'ce',
#   'd3',
#   'd5',
#   'd7',
#   'd8',
#   'd9',
#   'dc',
#   'dd',
#   'de',
#   'e0',
#   'e3',
#   'e4',
#   'e5',
#   'e8',
#   'e9',
#   'ea',
#   'eb',
#   'ec',
#   'ed',
#   'ee',
#   'f0',
#   'f3',
#   'f4',
#   'f6',
#   'f8',
#   'f9',
#   'fb',
#   'fe',
#   'info',
#   'pack'],
#  '../.git\\objects\\00',
#  [],
#  '../.git\\objects\\01',
#  [],
#  '../.git\\objects\\03',
#  [],
#  '../.git\\objects\\06',
#  [],
#  '../.git\\objects\\07',
#  [],
#  '../.git\\objects\\0b',
#  [],
#  '../.git\\objects\\0c',
#  [],
#  '../.git\\objects\\0d',
#  [],
#  '../.git\\objects\\13',
#  [],
#  '../.git\\objects\\14',
#  [],
#  '../.git\\objects\\17',
#  [],
#  '../.git\\objects\\19',
#  [],
#  '../.git\\objects\\1a',
#  [],
#  '../.git\\objects\\1b',
#  [],
#  '../.git\\objects\\1d',
#  [],
#  '../.git\\objects\\23',
#  [],
#  '../.git\\objects\\24',
#  [],
#  '../.git\\objects\\26',
#  [],
#  '../.git\\objects\\28',
#  [],
#  '../.git\\objects\\2c',
#  [],
#  '../.git\\objects\\2d',
#  [],
#  '../.git\\objects\\34',
#  [],
#  '../.git\\objects\\35',
#  [],
#  '../.git\\objects\\36',
#  [],
#  '../.git\\objects\\38',
#  [],
#  '../.git\\objects\\39',
#  [],
#  '../.git\\objects\\3a',
#  [],
#  '../.git\\objects\\3b',
#  [],
#  '../.git\\objects\\3d',
#  [],
#  '../.git\\objects\\3e',
#  [],
#  '../.git\\objects\\3f',
#  [],
#  '../.git\\objects\\40',
#  [],
#  '../.git\\objects\\41',
#  [],
#  '../.git\\objects\\43',
#  [],
#  '../.git\\objects\\44',
#  [],
#  '../.git\\objects\\46',
#  [],
#  '../.git\\objects\\47',
#  [],
#  '../.git\\objects\\48',
#  [],
#  '../.git\\objects\\49',
#  [],
#  '../.git\\objects\\4a',
#  [],
#  '../.git\\objects\\4c',
#  [],
#  '../.git\\objects\\51',
#  [],
#  '../.git\\objects\\52',
#  [],
#  '../.git\\objects\\53',
#  [],
#  '../.git\\objects\\54',
#  [],
#  '../.git\\objects\\55',
#  [],
#  '../.git\\objects\\56',
#  [],
#  '../.git\\objects\\57',
#  [],
#  '../.git\\objects\\58',
#  [],
#  '../.git\\objects\\59',
#  [],
#  '../.git\\objects\\5e',
#  [],
#  '../.git\\objects\\60',
#  [],
#  '../.git\\objects\\61',
#  [],
#  '../.git\\objects\\62',
#  [],
#  '../.git\\objects\\64',
#  [],
#  '../.git\\objects\\65',
#  [],
#  '../.git\\objects\\66',
#  [],
#  '../.git\\objects\\6b',
#  [],
#  '../.git\\objects\\6c',
#  [],
#  '../.git\\objects\\6e',
#  [],
#  '../.git\\objects\\6f',
#  [],
#  '../.git\\objects\\71',
#  [],
#  '../.git\\objects\\73',
#  [],
#  '../.git\\objects\\74',
#  [],
#  '../.git\\objects\\75',
#  [],
#  '../.git\\objects\\76',
#  [],
#  '../.git\\objects\\77',
#  [],
#  '../.git\\objects\\78',
#  [],
#  '../.git\\objects\\79',
#  [],
#  '../.git\\objects\\7c',
#  [],
#  '../.git\\objects\\7e',
#  [],
#  '../.git\\objects\\7f',
#  [],
#  '../.git\\objects\\81',
#  [],
#  '../.git\\objects\\85',
#  [],
#  '../.git\\objects\\86',
#  [],
#  '../.git\\objects\\89',
#  [],
#  '../.git\\objects\\8a',
#  [],
#  '../.git\\objects\\8b',
#  [],
#  '../.git\\objects\\8d',
#  [],
#  '../.git\\objects\\8f',
#  [],
#  '../.git\\objects\\90',
#  [],
#  '../.git\\objects\\91',
#  [],
#  '../.git\\objects\\92',
#  [],
#  '../.git\\objects\\94',
#  [],
#  '../.git\\objects\\96',
#  [],
#  '../.git\\objects\\97',
#  [],
#  '../.git\\objects\\99',
#  [],
#  '../.git\\objects\\9a',
#  [],
#  '../.git\\objects\\9c',
#  [],
#  '../.git\\objects\\9d',
#  [],
#  '../.git\\objects\\9e',
#  [],
#  '../.git\\objects\\9f',
#  [],
#  '../.git\\objects\\a0',
#  [],
#  '../.git\\objects\\a1',
#  [],
#  '../.git\\objects\\a3',
#  [],
#  '../.git\\objects\\a4',
#  [],
#  '../.git\\objects\\a5',
#  [],
#  '../.git\\objects\\a6',
#  [],
#  '../.git\\objects\\a7',
#  [],
#  '../.git\\objects\\a8',
#  [],
#  '../.git\\objects\\a9',
#  [],
#  '../.git\\objects\\aa',
#  [],
#  '../.git\\objects\\ab',
#  [],
#  '../.git\\objects\\ad',
#  [],
#  '../.git\\objects\\ae',
#  [],
#  '../.git\\objects\\b1',
#  [],
#  '../.git\\objects\\b2',
#  [],
#  '../.git\\objects\\b3',
#  [],
#  '../.git\\objects\\b4',
#  [],
#  '../.git\\objects\\b5',
#  [],
#  '../.git\\objects\\b7',
#  [],
#  '../.git\\objects\\b8',
#  [],
#  '../.git\\objects\\ba',
#  [],
#  '../.git\\objects\\bb',
#  [],
#  '../.git\\objects\\be',
#  [],
#  '../.git\\objects\\bf',
#  [],
#  '../.git\\objects\\c0',
#  [],
#  '../.git\\objects\\c1',
#  [],
#  '../.git\\objects\\c2',
#  [],
#  '../.git\\objects\\c4',
#  [],
#  '../.git\\objects\\c5',
#  [],
#  '../.git\\objects\\c7',
#  [],
#  '../.git\\objects\\c8',
#  [],
#  '../.git\\objects\\c9',
#  [],
#  '../.git\\objects\\ca',
#  [],
#  '../.git\\objects\\cb',
#  [],
#  '../.git\\objects\\cc',
#  [],
#  '../.git\\objects\\ce',
#  [],
#  '../.git\\objects\\d3',
#  [],
#  '../.git\\objects\\d5',
#  [],
#  '../.git\\objects\\d7',
#  [],
#  '../.git\\objects\\d8',
#  [],
#  '../.git\\objects\\d9',
#  [],
#  '../.git\\objects\\dc',
#  [],
#  '../.git\\objects\\dd',
#  [],
#  '../.git\\objects\\de',
#  [],
#  '../.git\\objects\\e0',
#  [],
#  '../.git\\objects\\e3',
#  [],
#  '../.git\\objects\\e4',
#  [],
#  '../.git\\objects\\e5',
#  [],
#  '../.git\\objects\\e8',
#  [],
#  '../.git\\objects\\e9',
#  [],
#  '../.git\\objects\\ea',
#  [],
#  '../.git\\objects\\eb',
#  [],
#  '../.git\\objects\\ec',
#  [],
#  '../.git\\objects\\ed',
#  [],
#  '../.git\\objects\\ee',
#  [],
#  '../.git\\objects\\f0',
#  [],
#  '../.git\\objects\\f3',
#  [],
#  '../.git\\objects\\f4',
#  [],
#  '../.git\\objects\\f6',
#  [],
#  '../.git\\objects\\f8',
#  [],
#  '../.git\\objects\\f9',
#  [],
#  '../.git\\objects\\fb',
#  [],
#  '../.git\\objects\\fe',
#  [],
#  '../.git\\objects\\info',
#  [],
#  '../.git\\objects\\pack',
#  [],
#  '../.git\\refs',
#  ['heads', 'remotes', 'tags'],
#  '../.git\\refs\\heads',
#  [],
#  '../.git\\refs\\remotes',
#  ['origin', 'upstream'],
#  '../.git\\refs\\remotes\\origin',
#  [],
#  '../.git\\refs\\remotes\\upstream',
#  [],
#  '../.git\\refs\\tags',
#  [],
#  '../.vscode',
#  [],
#  '../course_material',
#  ['slides'],
#  '../course_material\\slides',
#  [],
#  '../data',
#  [],
#  '../images',
#  [],
#  '../moodle_exercises',
#  [],
#  '../workbooks',
#  ['development_working_dir', 'file_list'],
#  '../workbooks\\development_working_dir',
#  [],
#  '../workbooks\\file_list',
#  []]

# %%
genList()[1]
# Out:
# ['000_Setup.ipynb',
#  '001a_python.py',
#  '001_programming_basics.ipynb',
#  '002_conditional_statements.ipynb',
#  '003_loops_old.ipynb',
#  [...]]

# %% [markdown]
# #### Exists
#
# We can also check if a file or folder exists. This is useful if we're going to be creating a new file or folder, and we want to make sure we don't overwrite something that already exists.

# %%
print(os.path.exists("chipotle.tsv"))
print(os.path.exists("mad_bitcoin_keys.tsv"))
# Out:
# True
# False

# %% [markdown]
# ### File Paths
#
# When navigating file systems we necessarily need to deal with file paths, or the locations in the file structure where each file is located. There are two types of file paths, absolute and relative.
#
# ![Paths](../../images/paths.png "Paths")
# ![Paths](../images/paths.png "Paths")
#
# #### Absolute Paths
#
# An absolute path is the full path to a file or folder. It starts at the root of the file system and lists each folder in the hierarchy, separated by a slash. For example, on my Mac, the root of the file system is "/". If I want to get to my home folder, I need to go to "/Users/". If I want to get to my Documents folder, I need to go to "/Users/akeem/Documents". If I want to get to my "downloads" folder, I need to go to "/Users/akeem/Downloads".
#
# Absolute file paths will rarely be relevant for us, it is relevant if you are writing lower level programs, that deal more directly with a file system. Note that different operating systems have different file systems, so the absolute path on a Mac is different than the absolute path on a PC - you can't rely on any particular configuration.
#
# <b>Note:</b> those environment variables that we mentioned above are some of the things that tell programs where to look for stuff, they indicate the root directories of things like the user's home folder, or the location of the program files.
#
# #### Relative Paths
#
# Relative paths are relative to the current working directory. If I am in the root directory of this repository, the relative path to each workbook is workbooks\workbook_name.ipynb. If I am in the workbooks folder, the relative path to each workbook is just the name of the workbook. If I am in the data folder, the relative path to each workbook is ../workbooks/workbook_name.ipynb.
#
# When working within a repository we use relative paths to refer to other files. This allows us to pass around the repository, or move it to a different machine, and things still work. For example, all the data and image references in these workbooks uses a relative path, so it works just fine on my Mac and your different computers without any issue. One important value when using relative paths is ../ which means "go up one level", so if we are in the "workbooks" folder here, we can use ../ to get to the root of the repository.
#
# ### Joining Paths
#
# When we need to deal with file paths we can use the os.path.join() function to join together the parts of the path. This is useful because it will automatically handle the differences between operating systems for us. For example, on a Mac the path separator is "/", while on a PC it is "\". The os.path.join() function will automatically use the correct separator for the operating system we are using.
#
# For example, to get the absolute path to a file, we can use the os.path.join() function to join together the current working directory and the relative path to the file.

# %%
file_name = "016_file_management_2.ipynb"
fold_path = os.getcwd()
print(f"File path: {os.path.join(fold_path, file_name)}")
# Out:
# File path: c:\Users\desla\Documents\Data Analytics\Programming_Basics_for_ML\workbooks\016_file_management_2.ipynb

# %% [markdown]
# ## Reading and Writing Text Files
#
# Now that we have an idea what is in our folders, we can start recklessly changing things. For example, we can use the os write functions to make a new CSV file and write some data to it. One thing that is reveled to us here that might not be visible is you're used to Windows machines is a look at what is a "text" file. Text files are .txt, but also .csv, .tsv, .py, etc... meaning all of these types of files is made up of just plain text, and we can edit them in any text editor on a computer - the file extension doesn't dictate it, that's for our convenience. The structure of our code will:
# <ul>
# <li> Open a connection to the file, if it doesn't exist this will create it. </li>
# <li> Perform the contents of the loop - writing some data to a file for 100 lines. </li>
# <li> When that writing task is complete, it will close the connection automatically thanks to the with. </li>
# </ul>
#
# In the open() function call to connect to the file we provide the second argument that defines what type of access we get to the file we are opening:
# <ul>
# <b><li> 'r' - read only </li>
# <li> 'w' - write only </li>
# <li> 'a' - append to the end of the file </li>
# <li> 'r+' - read and write </li></b>
# <li> 'w+' - write and read, overwrites existing files</li>
# </ul>
#
# These are mostly pretty simple and self-explanatory, with the exception of the distinction between r+ and w. The 'r+' option is a bit more complicated. This will open the file for reading and writing, but it will not create the file if it doesn't exist. If you try to open a file that doesn't exist with 'r+' you will get an error. The `w` option will create the file if it doesn't exist, but it will also overwrite the file if it does exist. So if we are making something brand new, we want `w`, but if we are attempting to update an existing file, we want `r+`. This is an easy place to make an error, so we should be careful. We can also check to see if the file we want to make already exists, then make a decision. `W+` is another weird option, it is read/write, but will overwrite the file if it exists.
#
# ![File Permissions](../../images/file_permissions.png "File Permissions" )
# ![File Permissions](../images/file_permissions.png "File Permissions" )
#
# Choosing the level of access of a file that we open is important in terms of writing our code to prevent errors. We want to open the file with the least impactful level of access that we need to have to do what we want. So if we are just reading data from a file, opening it as read only will prevent us accidentally changing that file in any way, as we don't even have the ability to do so. If we want a brand-new file, opening it as write only will prevent any old data that may have been hanging around from persisting. The more flexible the level of access, the more options we have for what we can do, the more likely it is that we may do something unintentional.
#
# <b>Note:</b> this will go to our current directory, wherever the pointer is, so if you got rid of that line to reset the locations, it would spit this file out to whatever folder you happen to be in.

# %% [markdown]
# #### Create a CSV with Fibonacci Numbers
#
# Here we'll make a CSV, fib.csv, that has two coulmns - an index and the fibonacci number at that index.

# %%
# write fibonacci series to a file
end_fib = 30

def fib(n):
    if n < 2:
        return n
    else:
        return fib(n-2) + fib(n-1)

with open("fib.csv", "w") as f:
    f.write("Index,Fibonacci Series\n")
    i = 0
    while i < end_fib:
        f.write(f"{i},{fib(i)}\n")
        print(f"{i},{fib(i)}")
        i += 1
print("Done")
# Out:
# 0,0
# 1,1
# 2,1
# 3,2
# 4,3
# 5,5
# 6,8
# 7,13
# 8,21
# 9,34
# 10,55
# 11,89
# 12,144
# 13,233
# 14,377
# 15,610
# 16,987
# 17,1597
# 18,2584
# 19,4181
# 20,6765
# 21,10946
# 22,17711
# 23,28657
# 24,46368
# 25,75025
# 26,121393
# 27,196418
# 28,317811
# 29,514229
# Done

# %% [markdown]
# #### Reading Our File
#
# Now that our file is written, we can read it and see what we got. We need to specify the `r` here, since we are only reading. When reading from a file, there's a few main options:
# <ul>
# <li> read() - read the entire file into a single string </li>
# <li> readline() - read the file one line at a time </li>
# <li> readlines() - read the file into a list of strings, one per line </li>
# </ul>
#
# The first, read, takes in the entire file into one string. This is fine for small files, but for things that are large it is unruly. For most things of size we probably want to navigate the file one line at a time, using the readline() option. There's also a common shortcut that we can do with a for loop that does this for us easily:
#
#     ``` for line in file: ```
#
# If we are reading in a large file, one line at a time is a better choice. Depending on what we are doing, we may be able to process our data and "deal with it" - whether that be saving it to another file or loading it into some dataset - on the fly. When we get to neural networks towards the end of machine learning, we'll try to read enough data so that our processor is busy - so the computer is never waiting for either data or a free processor. Loading batches allows us to make the most of the power of our computer, as we can minimize the amount of time any part of it spends waiting for something else to finish.

# %%
with open("fib.csv", "r") as f:
   header = next(f)
   for line in f:
      print(line)
# Out:
# 0,0
#
# 1,1
#
# 2,1
#
# 3,2
#
# 4,3
#
# 5,5
#
# 6,8
#
# 7,13
#
# 8,21
#
# 9,34
#
# 10,55
#
# 11,89
#
# 12,144
#
# 13,233
#
# 14,377
#
# 15,610
#
# 16,987
#
# 17,1597
#
# 18,2584
#
# 19,4181
#
# 20,6765
#
# 21,10946
#
# 22,17711
#
# 23,28657
#
# 24,46368
#
# 25,75025
#
# 26,121393
#
# 27,196418
#
# 28,317811
#
# 29,514229

# %%
with open("fib.csv", "r") as f:
    fib_list = f.readlines()
print(fib_list)
# Out:
# ['Index,Fibonacci Series\n', '0,0\n', '1,1\n', '2,1\n', '3,2\n', '4,3\n', '5,5\n', '6,8\n', '7,13\n', '8,21\n', '9,34\n', '10,55\n', '11,89\n', '12,144\n', '13,233\n', '14,377\n', '15,610\n', '16,987\n', '17,1597\n', '18,2584\n', '19,4181\n', '20,6765\n', '21,10946\n', '22,17711\n', '23,28657\n', '24,46368\n', '25,75025\n', '26,121393\n', '27,196418\n', '28,317811\n', '29,514229\n']

# %% [markdown]
# We can also read it into a CSV, for fun!

# %%
df2 = pd.read_csv("fib.csv", index_col=None)
print(df2)
# Out:
#     Index  Fibonacci Series
# 0       0                 0
# 1       1                 1
# 2       2                 1
# 3       3                 2
# 4       4                 3
# 5       5                 5
# 6       6                 8
# 7       7                13
# 8       8                21
# 9       9                34
# 10     10                55
# 11     11                89
# 12     12               144
# 13     13               233
# 14     14               377
# 15     15               610
# 16     16               987
# 17     17              1597
# 18     18              2584
# 19     19              4181
# 20     20              6765
# 21     21             10946
# 22     22             17711
# 23     23             28657
# 24     24             46368
# 25     25             75025
# 26     26            121393
# 27     27            196418
# 28     28            317811
# 29     29            514229

# %% [markdown]
# #### Seek
#
# When in a file, we can use the seek() function to move around. This is useful if we want to go back to the beginning of the file, or jump to a specific location. The seek() function takes in two arguments, the first is the location we want to go to, and the second is the reference point. The reference point can be 0, 1, or 2.
# <ul>
# <li>0 is the beginning of the file</li>
# <li>1 is the current location</li>
# <li>2 is the end of the file</li>
# </ul>
#
# So if we want to go to the beginning of the file, we can use seek(0,0). If we want to go to the end of the file, we can use seek(0,2). If we want to go to the 100th character in the file, we can use seek(100,0). If we want to go to the 100th character from the end of the file, we can use seek(-100,2).
#
# Note that in the examples below I've changed a couple of things - the open uses "rb" or "read binary" instead of "r" or "read". This is to allow us to do the offsets from the end or the current position - the system needs to deal with the binary file. Second, I've added that decode statement to the print statement. This is because the file is binary, so we need to decode it to get it into a string that we can print nicely. Note the last one - I didn't change the encoding. Text encoding is something we need to deal with, but something that is minor - we basically need to make sure that we are using the encoding that matches the file, or we need to re-encode it.
#
# #### Tell
#
# We can also use the tell() function to find out where we are in the file. This is useful if we want to jump around, but we don't know where we are. We can use tell() to find out where we are, then use seek() to go somewhere else.

# %%
# Open fib and seek/tell
with open("fib.csv", "rb") as f:
    print("At the stat of the file:")
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 150:")
    f.seek(150, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 20, relative to the current position of 150:")
    f.seek(20, os.SEEK_CUR)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 5:")
    f.seek(5, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At the end:")
    f.seek(0, os.SEEK_END)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("Moving back from the end:")
    f.seek(-5, 2)
    print("Position", f.tell())
    print(f.readline())
# Out:
# At the stat of the file:
# Position 0
# Index,Fibonacci Series
#
# At position 150:
# Position 150
# 9,4181
#
# At position 20, relative to the current position of 150:
# Position 178
# 2,17711
#
# At position 5:
# Position 5
# ,Fibonacci Series
#
# At the end:
# Position 261
#
# Moving back from the end:
# Position 256
# b'229\r\n'

# %% [markdown]
# #### Appending a File and the In-File Pointer
#
# Another of the options above that is a little odd is the `a`, for append. This will open the file and add new data to the end of it, but it will not overwrite the existing data. This is useful if we want to add new data to an existing file, but we don't want to lose the old data. This is very useful for things like logs - we likely have a pretty substantial amount of data accumulated in a big text file and we want to add new stuff without losing the old data or having to deal with the old data at all. We can use this to basically tack some entries onto the end of a file easily.
#
# This issue of opening an existing file normally vs appending seems pretty minor, but it can have larger performance implications than we might expect. For example, server logs can be many, many GB of text that lists errors or warnings going back years. We want to keep the log, and we also want to add today's entries. Opening a 2GB file "normally", navigating to the end, then spitting it back out can be slow, appending directly to the end of that same file is fast. This is because just like navigating a file system, a text file itself has a pointer that maintains your position - think of it as an invisible cursor just like we have in any program where we type. Append puts that position cursor directly at the end, and just starts writing. Personally, I once had a job where I remade a little program that went to approximately 150 servers, grabbed their log file, and looked for last night's entry at the end of the file to see if a backup failed. By changing it from opening the files normally, to appending (roughly, the language wasn't Python), I cut the runtime from 4 to 5 hours to about <10 minutes - without making any actual improvements to the logic of the code, just by jumping directly to the end of the text. When someone wrote the original, all the log files were probably tiny, as the system was new, so it didn't matter for performance; as things grew, this became an issue.
#
# <b>Note:</b> the "it's slow to open a large file and write to the end" thing is obviously a common issue for computers in general. File access packages know this, and are built to be fast no matter what. This idea is still true, just less true than it is with older software.

# %%
with open("fib.csv", "a") as f:
    print(f.tell())
# Out:
# 230

# %% [markdown]
# ## Exercise
#
# Complete the spotReader function to take in a file and a spot in that file, and return that line.

# %%
def spotReader(filepath, spot):
    ret_val = ""
    with open(filepath, "r") as f:
        f.seek(spot, 0)
        ret_val = f.readline()
    return ret_val

# %%
spotReader("fib.csv", 150)
# Out:
# '946\n'

# %% [markdown]
# ### Remote Data
#
# We can also use some code to programmatically download data from the internet. This can save us from having to download large files, but it can also help us to build automated pipelines for getting data.
#
# One thing that I've worked on a lot in industry is importing data from other systems into LMS systems like Moodle. A common process to do this is for the other system to export a CSV file to a specific location on a file server, then a script that we created will grab the new file from the pre-defined location and feed it into our import work. Applications for personal use are also broad - we could automate downloads of files that are regularly updated.
#
# For pretty much any data source that we might want to be able to access, there is likely a library that will do so. So we can access FTP servers, different file share protocols, and so on - we just need to look up the correct tool for whichever data source we want to access.
#
# <b>Note:</b> there are many libraries that download files, they're pretty much interchangeable. I'm using `urllib.request` here because it's built into Python and is the "basic standard", but you could also use `requests` or `wget` or `curl` or any number of other libraries. For this, and the others, look at the documentation to see the options and how to use the functions - they are generally similar to this, just provide a URL and a destination.

# %%
# Download
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
import urllib.request
try:
    urllib.request.urlretrieve(url, 'chipotle.tsv')
except:
    print("Error downloading file")

# %% [markdown]
# ### Compression
#
# Many files that we deal with, particularly when downloading datasets, may be compressed. Several libraries provide tools for us to programmatically deal with these files, including decompressing them and moving their files into our working directory.
#
# <b>Note:</b> Pandas read_csv function can also read compressed files directly, so you can load my_data.zip or similar with no interim decompression step.

# %%
# Compress some files
import zipfile

# Zip first 5 files in file_list
with zipfile.ZipFile('file_list.zip', 'w') as myzip:
    for file in range(5):
        myzip.write(file_list[file])

# %% [markdown]
# Decompress into a folder

# %%
# Decompress file_list.zip into file_list folder
with zipfile.ZipFile('file_list.zip', 'r') as myzip:
    myzip.extractall('file_list')

# %% [markdown]
# ## Exercise
#
# Create the function ipynb crawler. When given a director, assemble and return a list of all .ipynb files in that directory and all subdirectories.

# %%
def ipynbCrawler(directory_targ="../"):
    """
    Crawl a directory and return a list of all ipynb files
    """
    ipynb_list = []
    for root, directories, files in os.walk(directory_targ):
        for file in files:
            if file.endswith(".ipynb"):
                ipynb_list.append(os.path.join(root, file))
    return ipynb_list

# %%
ipynbCrawler()
# Out:
# ['../010_class_comments.ipynb',
#  '../011_looping_2_data.ipynb',
#  '../005_file_access.ipynb',
#  '../007_other_data_structures_full_sol.ipynb',
#  '../006_objects.ipynb',
#  '../012_algorithm_design_sol.ipynb',
#  '../002_conditional_statements.ipynb',
#  '../005a_File_Loading_example_from_stats.ipynb',
#  '../004_functions.ipynb',
#  '../009_strings_sol.ipynb',
#  '../COPY-012_algorithm_design copy.ipynb',
#  '../COPY-015_overloading.ipynb',
#  '../013_arrays_and_numpy_sol.ipynb',
#  '../009_strings.ipynb',
#  '../011_looping_2_data_sol.ipynb',
#  '../014_map_apply.ipynb',
#  '../014_map_apply_sol.ipynb',
#  '../COPY-014_map_apply.ipynb',
#  '../012_algorithm_design.ipynb',
#  '../013_arrays_and_numpy.ipynb',
#  '../000_Setup.ipynb',
#  '../015_overloading_sol.ipynb',
#  '../001_programming_basics.ipynb',
#  '../COPY-013_arrays_and_numpy.ipynb',
#  '../007_other_data_structures.ipynb',
#  '../003_loops.ipynb',
#  '../015_overloading.ipynb',
#  '../008_recursion.ipynb',
#  '../file_list/010_class_comments.ipynb',
#  '../file_list/011_looping_2_data.ipynb',
#  '../file_list/005_file_access.ipynb',
#  '../file_list/007_other_data_structures_full_sol.ipynb',
#  '../development_working_dir/010_class_comments.ipynb',
#  '../development_working_dir/005_file_access.ipynb',
#  '../development_working_dir/006_objects.ipynb',
#  '../development_working_dir/002_conditional_statements.ipynb',
#  '../development_working_dir/z00_classes.ipynb',
#  '../development_working_dir/overloading_sol.ipynb',
#  '../development_working_dir/005a_File_Loading_example_from_stats.ipynb',
#  '../development_working_dir/004_functions.ipynb',
#  '../development_working_dir/009_strings_sol.ipynb',
#  '../development_working_dir/016_file_management_2.ipynb',
#  '../development_working_dir/COPY-Asn_1_sol.ipynb',
#  '../development_working_dir/013_arrays_and_numpy_sol.ipynb',
#  '../development_working_dir/inheritance.ipynb',
#  '../development_working_dir/011_looping_2_data_sol.ipynb',
#  '../development_working_dir/014_map_apply_sol.ipynb',
#  '../development_working_dir/012_algorithm_design.ipynb',
#  '../development_working_dir/multip_inh.ipynb',
#  '../development_working_dir/000_Setup.ipynb',
#  '../development_working_dir/tmp.ipynb',
#  '../development_working_dir/001_programming_basics.ipynb',
#  '../development_working_dir/arrays_and_numpy_sol.ipynb',
#  '../development_working_dir/string_processing.ipynb',
#  '../development_working_dir/007_other_data_structures.ipynb',
#  '../development_working_dir/003_loops.ipynb',
#  '../development_working_dir/008_recursion.ipynb',
#  '../development_working_dir/file_list/010_class_comments.ipynb',
#  '../development_working_dir/file_list/005_file_access.ipynb',
#  '../development_working_dir/file_list/006_objects.ipynb']

# %%
inputFile = open("Lab5_input.txt", "r")
char = inputFile.read(1)
while char != "" :
     print(char)
     char = inputFile.read(1)
inputFile.close()
# Out:
# a
# s
# p
# i
# r
# a
# t
# i
# o
# n
#
#
# c
# l
# a
# s
# s
# i
# f
# i
# e
# d
#
#
# f
# e
# d
# e
# r
# a
# t
# i
# o
# n
#
#
# g
# r
# a
# d
# u
# a
# t
# i
# o
# n
#
#
# m
# i
# l
# l
# e
# n
# n
# i
# u
# m
#
#
# p
# h
# i
# l
# o
# s
# o
# p
# h
# y
#
#
# q
# u
# a
# d
# r
# a
# t
# i
# c
# s
#
#
# t
# r
# a
# n
# s
# c
# r
# i
# p
# t
#
#
# w
# i
# l
# d
# e
# r
# n
# e
# s
# s
#
#
# z
# o
# o
# l
# o
# g
# i
# s
# t
# s

# %%
letterCounts = [0] * 26
inputFile = open("Lab5_input.txt", "r")
char = inputFile.read(1)
while char != "" :
   char = char.upper() 
   if char >= "A" and char <= "Z" :
      code = ord(char) - ord("A")
      letterCounts[code] = letterCounts[code] + 1
   char = inputFile.read(1)
inputFile.close()
print(letterCounts[1])
# Out:
# 0
